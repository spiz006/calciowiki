# %%
# %load_ext autoreload
# %autoreload 2

import calciowiki as cw
import logging
logging.basicConfig(level=logging.DEBUG)

# %%
j='Juventus_Football_Club_2021-2022'
x = cw.WikiSeasonIt(title=j)
# Out:
# DEBUG:root:Getting Page: Juventus_Football_Club_2021-2022
# DEBUG:root:Processing season for club: Juventus FC.
# rig
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# rig
#
#
#
#
#
#
# rig
#
#
#
#
#
#
#
# rig
# rig
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# rig
#
#
# aut
#
#
# rig
#
#
#
#
# rig
#
#
# aut
#
#
#
#
#
#
# rig

# %%
x.season['events'].head()
# Out:
#   time    player  type desc    match_time      team season
# 0   51   Pereyra  goal  pen  1.629650e+09   Udinese  21-22
# 1   83  Deulofeu  goal       1.629650e+09   Udinese  21-22
# 0    3    Dybala  goal       1.629650e+09  Juventus  21-22
# 1   23  Cuadrado  goal       1.629650e+09  Juventus  21-22
# 0   21   Mancuso  goal       1.630176e+09    Empoli  21-22

# %%
import mwparserfromhell
import pandas as pd

# %%
classifica = {}
classifica['sa'] = "Serie_A_2021-2022"
classifica['saf'] = "Serie_A_2021-2022_(calcio_femminile)"
classifica['sc'] = "Serie_C_2021-2022"

# %%
x = cw.WikiClassifica(classifica['sa'])
# Out:
# DEBUG:root:Getting Page: Serie_A_2021-2022

# %%
display(x.classifica)
# Out:
#     Position         Team  Points  Played  Won  Draw  Lost  Goals Scored  \
# 0          1        Milan      56      26   17     5     4            52
# 1          2        Inter      54      24   16     6     2            55
# 2          3       Napoli      53      25   16     5     4            46
# 3          4     Juventus      47      26   13     8     5            38
# 4          5     Atalanta      44      24   12     8     4            46
# 5          6        Lazio      42      25   12     6     7            52
# 6          7         Roma      41      26   12     5     9            44
# 7          8   Fiorentina      39      24   12     3     9            43
# 8          9       Verona      37      26   10     7     9            49
# 9         10       Torino      33      25    9     6    10            32
# 10        11       Empoli      31      26    8     7    11            38
# 11        12     Sassuolo      30      25    7     9     9            41
# ...
